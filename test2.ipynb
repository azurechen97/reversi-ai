# %%
from environment import *
from ai import *
from utils import *

# %%
reversi = Reversi()
ai1 = ArtificialIdiot()
ai2 = EasyAI()
ai3 = NormalAI()
ai4 = HardAI()

# %%
ai3.play(reversi)
# Out:
# Game start!
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2
# 3       ○ ●
# 4       ● ○
# 5
# 6
# 7
# Black's turn!
# Enter your move (i j) or command (pause/stop/hint):
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2
# 3       ○ ●
# 4       ● ●
# 5         ●
# 6
# 7
# White's turn!
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2
# 3       ○ ●
# 4       ○ ●
# 5       ○ ●
# 6
# 7
# White plays at (5,3).
# Black's turn!
# Enter your move (i j) or command (pause/stop/hint):
# Game over!
# Draw! 3:3

# %%
reversi.print_board()
# Out:
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2
# 3       ○ ●
# 4       ○ ●
# 5       ○ ●
# 6
# 7

# %%
reversi.reset()

# %%
reversi.print_board()
# Out:
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2
# 3       ○ ●
# 4       ● ○
# 5
# 6
# 7

# %%
reversi.reset()
ai_vs_ai(ai2,ai3,reversi,round_num=1,verbose=3)
# Out:
# Round 0
# Game start!
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2
# 3       ○ ●
# 4       ● ○
# 5
# 6
# 7
# Black's turn!
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2
# 3       ○ ●
# 4       ● ● ●
# 5
# 6
# 7
# White plays at (4,5).
# White's turn!
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2
# 3       ○ ●
# 4       ○ ● ●
# 5       ○
# 6
# 7
# Black plays at (5,3).
# Black's turn!
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2
# 3       ○ ●
# 4     ● ● ● ●
# 5       ○
# 6
# 7
# White plays at (4,2).
# White's turn!
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2
# 3       ○ ●
# 4     ○ ● ● ●
# 5   ○   ○
# 6
# 7
# Black plays at (5,1).
# Black's turn!
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2     ●
# 3       ● ●
# 4     ○ ● ● ●
# 5   ○   ○
# 6
# 7
# White plays at (2,2).
# White's turn!
#   0 1 2 3 4 5 6 7
# 0
# 1
# 2     ●   ○
# 3       ○ ●
# 4     ○ ● ● ●
# 5   ○   ○
# 6
# 7
# Black plays at (2,4).
# Black's turn!
#   0 1 2 3 4 5 6 7
# 0
# 1         ●
# 2     ●   ●
# 3       ○ ●
# 4     ○ ● ● ●
# 5   ○   ○
# 6
# 7
# White plays at (1,4).
# White's turn!
# ...
